# %% [markdown]
# # Testing the Songdata

# %%
import pandas as pd

df = pd.read_csv("song_data.csv")
df
# Out:
#                                     track_name            track_artist  \
# 0                                 Dance Monkey             Tones and I
# 1                                      ROXANNE          Arizona Zervas
# 2                              Blinding Lights              The Weeknd
# 3                                      Circles             Post Malone
# 4                                         Tusa                 KAROL G
# ...                                        ...                     ...
# 3834                 Quem me Colocou pra Beber  Os Barões Da Pisadinha
# 3835                          Bark at the Moon           Ozzy Osbourne
# 3836  Ain't Talkin' 'Bout Love - 2015 Remaster               Van Halen
# 3837                                    MMMBop                  Hanson
# 3838                     Many Men (Wish Death)                 50 Cent
#
#       track_popularity                             track_album_name  \
# ...

# %%
df_selection = df[df['track_artist'] == 'Ed Sheeran']

df_selection = df_selection[["track_artist", "track_name"]]

print(df_selection)
# Out:
#      track_artist                                         track_name
# 36     Ed Sheeran  South of the Border (feat. Camila Cabello & Ca...
# 44     Ed Sheeran                  I Don't Care (with Justin Bieber)
# 58     Ed Sheeran                    Beautiful People (feat. Khalid)
# 114    Ed Sheeran                                            Perfect
# 133    Ed Sheeran                                       Shape of You
# 189    Ed Sheeran                                         Photograph
# 244    Ed Sheeran                                  Thinking out Loud
# 482    Ed Sheeran                                        Galway Girl
# 896    Ed Sheeran                Perfect Duet (Ed Sheeran & Beyoncé)
# 1420   Ed Sheeran                      Best Part of Me (feat. YEBBA)
# 1621   Ed Sheeran      Cross Me (feat. Chance the Rapper & PnB Rock)
# 2665   Ed Sheeran  South of the Border (feat. Camila Cabello & Ca...
# 3149   Ed Sheeran  Beautiful People (feat. Khalid) - Jack Wins Remix
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'track_artist', 'track_popularity', 'track_album_name',
#        'track_album_release_date', 'playlist_genre', 'duration_ms', 'lyrics'],
#       dtype='object')

# %% [markdown]
# # Notes

# %% [markdown]
# - testing the Lyrics embedding
# - if lyrics embeddings are not good I'll test summarizing and extracting the sense with an LLM
