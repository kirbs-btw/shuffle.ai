# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spotify_songs.csv")

# %%
drop_columns_arr = ['danceability', 'energy', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'playlist_id', 'track_album_id', 'key', 'mode', 'playlist_name', 'playlist_subgenre', 'track_id']


# could track_popularity be used to rank the results ? 
df = df.drop(columns=drop_columns_arr)

# %%
df = df.sort_values("track_popularity", ascending=False)

# don't like this because tracks could be the same name from different artists
df = df.drop_duplicates(subset=['track_artist'], keep='first') 
df = df.reset_index(drop=True)
df
# Out:
#                      track_name     track_artist  track_popularity  \
# 0                  Dance Monkey      Tones and I               100
# 1                       ROXANNE   Arizona Zervas                99
# 2               Blinding Lights       The Weeknd                98
# 3                       The Box      Roddy Ricch                98
# 4                          Tusa          KAROL G                98
# ...                         ...              ...               ...
# 10688  Keep Their Heads Ringing   Friday/Dr. Dre                 0
# 10689             Te Quiero Ver           Ceaese                 0
# 10690   Loco por Volverte a Ver  Chili Fernandez                 0
# 10691              Land of Dust           Lowkey                 0
# 10692    Heart (Samuraii Remix)         Stonefox                 0
#
#                                   track_album_name track_album_release_date  \
# 0      Dance Monkey (Stripped Back) / Dance Monkey               2019-10-17
# 1                                          ROXANNE               2019-10-10
# 2                                  Blinding Lights               2019-11-29
# 3            Please Excuse Me For Being Antisocial               2019-12-06
# 4                                             Tusa               2019-11-07
# ...                                            ...                      ...
# 10688                           We Got It Covered!                     2003
# 10689                                       Utopia               2018-08-16
# 10690                      Amor, Familia y Respeto               2004-05-19
# 10691                          Astral Wars, Vol. 1               2016-05-07
# 10692              Heart (Samuraii Remix) - Single               2014-11-12
#
#       playlist_genre  duration_ms
# 0              latin       209438
# 1                r&b       163636
# 2                r&b       201573
# 3              latin       196653
# 4                r&b       200960
# ...              ...          ...
# 10688            rap       238498
# 10689          latin       205189
# 10690          latin       225985
# 10691            edm       482420
# 10692            pop       343846
#
# [10693 rows x 7 columns]
